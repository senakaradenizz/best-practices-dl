# %%
import os
import re

# %%
truthful_pos = 'opinion_spam/positive/truthful/'
truthful_neg = 'opinion_spam/negative/truthful/'

deceptive_pos = 'opinion_spam/positive/deceptive/'
deceptive_neg = 'opinion_spam/negative/deceptive/'

truthful_reviews_link = []


if os.path.isdir(truthful_pos):
    for f in os.listdir(truthful_pos):
        fileLink = os.path.join(truthful_pos, f)
        truthful_reviews_link.append(fileLink)

if os.path.isdir(truthful_neg):
    for f in os.listdir(truthful_neg):
        fileLink = os.path.join(truthful_neg, f)
        truthful_reviews_link.append(fileLink)


deceptive_reviews_link = []

if os.path.isdir(deceptive_pos):
    for f in os.listdir(deceptive_pos):
        fileLink = os.path.join(deceptive_pos, f)
        deceptive_reviews_link.append(fileLink)

if os.path.isdir(deceptive_neg):
    for f in os.listdir(deceptive_neg):
        fileLink = os.path.join(deceptive_neg, f)
        deceptive_reviews_link.append(fileLink)
        
print('Number of truthfuls reviews ', len(truthful_reviews_link))
print('Number of deceptives reviews ', len(deceptive_reviews_link))
# Out:
# Number of truthfuls reviews  800
# Number of deceptives reviews  800

# %%
print(truthful_reviews_link)
# Out:
# ['opinion_spam/positive/truthful/t_omni_15.txt', 'opinion_spam/positive/truthful/t_hilton_17.txt', 'opinion_spam/positive/truthful/t_affinia_14.txt', 'opinion_spam/positive/truthful/t_ambassador_7.txt', 'opinion_spam/positive/truthful/t_allegro_5.txt', 'opinion_spam/positive/truthful/t_sheraton_1.txt', 'opinion_spam/positive/truthful/t_monaco_19.txt', 'opinion_spam/positive/truthful/t_knickerbocker_13.txt', 'opinion_spam/positive/truthful/t_amalfi_19.txt', 'opinion_spam/positive/truthful/t_hardrock_16.txt', 'opinion_spam/positive/truthful/t_affinia_16.txt', 'opinion_spam/positive/truthful/t_sheraton_17.txt', 'opinion_spam/positive/truthful/t_omni_13.txt', 'opinion_spam/positive/truthful/t_ambassador_11.txt', 'opinion_spam/positive/truthful/t_james_16.txt', 'opinion_spam/positive/truthful/t_hardrock_15.txt', 'opinion_spam/positive/truthful/t_hyatt_20.txt', 'opinion_spam/positive/truthful/t_palmer_6.txt', 'opinion_spam/positive/truthful/t_monaco_8.txt', 'opinion_spam/positive/truthful/
# ...

# %%
def clean_str(string):
    string = re.sub(r"[^A-Za-z0-9(),!?\'\`]", " ", string)
    string = re.sub(r"\'s", " \'s", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"n\'t", " n\'t", string)
    string = re.sub(r"\'re", " \'re", string)
    string = re.sub(r"\'d", " \'d", string)
    string = re.sub(r"\'ll", " \'ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)
    return string.strip().lower()

def handleFile(filePath):
    with open(filePath, "r") as f:
        lines=f.readlines()
        file_voc = []
        file_numWords = 0
        for line in lines:
            cleanedLine = clean_str(line)
            cleanedLine = cleanedLine.strip()
            cleanedLine = cleanedLine.lower()
            words = cleanedLine.split(' ')
            file_numWords = file_numWords + len(words)
            file_voc.extend(words)
    return file_voc, file_numWords

allFilesLinks = truthful_reviews_link + deceptive_reviews_link
vocabulary = []
numWords = []
for fileLink in allFilesLinks:
    file_voc, file_numWords = handleFile(fileLink)
    vocabulary.extend(file_voc)
    numWords.append(file_numWords)

#buradaki set fonksiyonu birden fazla olan kelimeleri teke düşürüyor
vocabulary = set(vocabulary)
vocabulary = list(vocabulary)

print('The total number of files is ', len(numWords))
print('The total number of words in the files is ', sum(numWords))
print('Vocabulary size is ', len(vocabulary))
# Out:
# The total number of files is  1600
# The total number of words in the files is  253157
# Vocabulary size is  9687

# %%
print(vocabulary)
# Out:
# ['blaming', 'evidently', 'unprofessional', 'theatre', 'einstein', 'perks', 'urgent', 'privacy', 'prom', 'fingertips', 'superb', 'signing', 'mattresses', 'modular', 'distance', 'shuttling', 'dog', 'processor', 'wonderland', 'connecting', 'affraid', 'flors', 'grandma', 'touristy', "bars'", 'unlocked', 'reached', '11', 'sale', 'nightmares', 'inexcusable', 'sofabed', 'permits', 'cooled', 'timetable', 'temper', 'functioning', 'quick', 'deck', 'andi', 'forgo', 'christy', 'difficulties', 'bell', 'received', 'personnel', 'has', 'lunch', 'serene', 'takes', 'scherer', 'inviting', 'history', 'tablet', 'hardened', 'incidentals', 'headboards', 'connection', 'western', 'incredible', 'leaked', 'buckingham', 'mattered', 'unbeatable', 'sexual', 'pre', 'profanities', 'exuberant', 'creatively', 'ensuing', 'clouds', 'cookie', 'polka', 'valuable', 'steak', 'trigger', 'swept', 'trite', 'unruly', 'ideas', 'riding', 'train', 'que', 'points', 'aspect', 'transfer', 'steamer', 'glaring', 'found', 'because', 'c
# ...

# %%
print(numWords)
# Out:
# [179, 69, 138, 222, 138, 49, 114, 125, 120, 102, 95, 112, 465, 70, 361, 125, 222, 61, 121, 129, 196, 174, 160, 93, 40, 100, 108, 65, 129, 69, 246, 101, 147, 160, 159, 235, 118, 110, 143, 241, 197, 132, 87, 69, 80, 106, 123, 148, 79, 143, 48, 44, 59, 178, 166, 56, 88, 137, 247, 97, 119, 141, 102, 52, 110, 131, 85, 115, 133, 271, 115, 69, 42, 92, 124, 77, 171, 49, 91, 65, 155, 84, 109, 94, 95, 105, 102, 197, 335, 83, 131, 126, 194, 158, 78, 108, 417, 111, 310, 156, 64, 98, 94, 82, 191, 190, 107, 119, 47, 259, 114, 97, 102, 146, 69, 111, 83, 57, 106, 174, 115, 126, 77, 97, 82, 199, 175, 48, 99, 114, 85, 183, 98, 193, 179, 347, 46, 408, 225, 217, 66, 242, 103, 81, 359, 160, 30, 104, 99, 133, 173, 241, 114, 189, 72, 78, 60, 147, 232, 153, 86, 137, 64, 57, 191, 130, 93, 114, 114, 141, 107, 118, 63, 184, 48, 111, 201, 123, 193, 166, 61, 71, 85, 62, 160, 97, 105, 77, 69, 88, 157, 83, 67, 210, 198, 99, 57, 41, 92, 132, 199, 116, 71, 108, 79, 155, 58, 83, 222, 135, 316, 105, 42, 71, 130, 106, 
# ...

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

words = [stemmer.stem(w.lower()) for w in vocabulary if w != "?"]

# %%
print(words)
# Out:
# ['blame', 'evid', 'unprofession', 'theatr', 'einstein', 'perk', 'urgent', 'privaci', 'prom', 'fingertip', 'superb', 'sign', 'mattress', 'modular', 'distanc', 'shuttl', 'dog', 'processor', 'wonderland', 'connect', 'affraid', 'flor', 'grandma', 'touristi', 'bar', 'unlock', 'reach', '11', 'sale', 'nightmar', 'inexcus', 'sofab', 'permit', 'cool', 'timet', 'temper', 'function', 'quick', 'deck', 'andi', 'forgo', 'christi', 'difficulti', 'bell', 'receiv', 'personnel', 'has', 'lunch', 'seren', 'take', 'scherer', 'invit', 'histori', 'tablet', 'harden', 'incident', 'headboard', 'connect', 'western', 'incred', 'leak', 'buckingham', 'matter', 'unbeat', 'sexual', 'pre', 'profan', 'exuber', 'creativ', 'ensu', 'cloud', 'cooki', 'polka', 'valuabl', 'steak', 'trigger', 'swept', 'trite', 'unruli', 'idea', 'ride', 'train', 'que', 'point', 'aspect', 'transfer', 'steamer', 'glare', 'found', 'becaus', 'client', 'chop', 'hospit', 'slowli', 'touch', 'lion', 'mad', 'wastebasket', 'recov', 'umcomfort', 'valet
# ...

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english')) 

print(stop_words)
# Out:
# {'before', 'aren', "wouldn't", 'were', 'myself', 'weren', 'is', 'off', 'few', 'only', 'during', 'y', "you'd", 'themselves', 'am', 'haven', 'own', 'himself', 'wasn', 'won', 'very', "you've", 'had', 'until', 'against', 'the', 'than', "couldn't", 'don', "shan't", 'from', 'their', 'both', 'my', 'yourselves', 'most', "didn't", "shouldn't", "you'll", 'he', 'out', 'what', 'should', 'mustn', "aren't", "needn't", 'isn', 'at', 'same', 'this', 'do', 'o', 'hadn', 'been', 'now', 'our', 'having', 'me', 'some', 'has', 've', 'couldn', 'in', 'its', 'being', 'more', 'needn', 'ours', 'such', "don't", 'itself', 'or', 'shouldn', 'if', "hadn't", "hasn't", "you're", 'theirs', "wasn't", 'we', 'by', 'to', 'whom', 'can', "that'll", 'which', "won't", 'why', 'd', 'her', 'because', 'mightn', 'be', "weren't", 'any', 'will', 'all', 'your', 'where', "haven't", 'ain', 'with', 'further', 'not', 'have', 'ma', 'a', 'she', 'you', 'just', "she's", 'these', 'wouldn', 'on', 'then', 'i', 'herself', 'about', 'below', "isn't"
# ...

# %%
filtered_words = [w for w in words if not w in stop_words]  
  
filtered_words = []  
  
for w in words:  
    if w not in stop_words:  
        filtered_words.append(w)  
  
print(len(words))  
print(len(filtered_words))
# Out:
# 9687
# 9535

# %%
print(filtered_words)
# Out:
# ['blame', 'evid', 'unprofession', 'theatr', 'einstein', 'perk', 'urgent', 'privaci', 'prom', 'fingertip', 'superb', 'sign', 'mattress', 'modular', 'distanc', 'shuttl', 'dog', 'processor', 'wonderland', 'connect', 'affraid', 'flor', 'grandma', 'touristi', 'bar', 'unlock', 'reach', '11', 'sale', 'nightmar', 'inexcus', 'sofab', 'permit', 'cool', 'timet', 'temper', 'function', 'quick', 'deck', 'andi', 'forgo', 'christi', 'difficulti', 'bell', 'receiv', 'personnel', 'lunch', 'seren', 'take', 'scherer', 'invit', 'histori', 'tablet', 'harden', 'incident', 'headboard', 'connect', 'western', 'incred', 'leak', 'buckingham', 'matter', 'unbeat', 'sexual', 'pre', 'profan', 'exuber', 'creativ', 'ensu', 'cloud', 'cooki', 'polka', 'valuabl', 'steak', 'trigger', 'swept', 'trite', 'unruli', 'idea', 'ride', 'train', 'que', 'point', 'aspect', 'transfer', 'steamer', 'glare', 'found', 'becaus', 'client', 'chop', 'hospit', 'slowli', 'touch', 'lion', 'mad', 'wastebasket', 'recov', 'umcomfort', 'valet', 'pum
# ...

# %%
import pickle

#eğer bu satırı tekrar çalıştıracaksan eski pickle dosyasını sil
with open("data.pickle", "wb") as f:
            pickle.dump((filtered_words), f)
